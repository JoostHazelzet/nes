# %%
from nes import NES

import matplotlib.pyplot as plt
# %matplotlib inline

mynes = NES("./roms/Super Mario Bros. (Japan, USA).nes", 
            verbose=False, headless=True)
buffer = mynes.run_frame_headless(run_frames=60)
plt.figure(figsize=(7.5, 7))
plt.imshow(buffer)
# Out:
# pygame 2.6.0 (SDL 2.28.4, Python 3.12.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# /tmp/ipykernel_597264/224524622.py:6: UserWarning: Selected sync_mode is SYNC_AUDIO, but audio is not available, probably because pyaudio is not available on the system
#   mynes = NES("./roms/Super Mario Bros. (Japan, USA).nes",
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 6 mynes = NES("./roms/Super Mario Bros. (Japan, USA).nes",
#       7             verbose=False, headless=True)
#       8 buffer = mynes.run_frame_headless(run_frames=60)
#       9 plt.figure(figsize=(7.5, 7))
#
# File ~/projects/2-custom-packages/nes/nes/cycore/system.pyx:160, in nes.cycore.system.NES.__init__()
#     158 self.interrupt_listener = InterruptListener()
#     159
# --> 160 rom = ROM(rom_file, verbose=verbose)
#     161 # the cartridge is a piece of hardware (unlike the ROM, which is just data) and must come first because it
#     162 # supplies bits of hardware (memory in most cases, both ROM and RAM) all over the system, so it
#
# File ~/projects/2-custom-packages/nes/nes/rom.py:55, in ROM.__init__(self, filename, verbose, py_compatibility_mode)
#      52 self.verbose = verbose
#      54 if filename is not None:
# ---> 55     self.load(filename)
#
# File ~/projects/2-custom-packages/nes/nes/rom.py:61, in ROM.load(self, filename)
#      57 def load(self, filename, ):
#      58     """
#      59     Load a ROM in the standard .nes file format
#      60     """
# ---> 61     with open(filename, "rb") as f:
#      62         nesheader = f.read(16)
#      63         self.decode_header(nesheader)
#
# FileNotFoundError: [Errno 2] No such file or directory: './roms/Super Mario Bros. (Japan, USA).nes'

# %%
buffer = mynes.run_frame_headless(run_frames=180, 
                                  controller1_state=[0,0,0,1,0,0,0,0])
plt.figure(figsize=(7.5, 7))
plt.imshow(buffer)

# %%
buffer = mynes.run_frame_headless(run_frames=30, 
                                  controller1_state=[1,0,0,0,0,0,0,0])
plt.figure(figsize=(7.5, 7))
plt.imshow(buffer)
